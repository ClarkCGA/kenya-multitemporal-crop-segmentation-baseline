# %%
import os, sys, copy, time, math, random, numbers, itertools, tqdm, importlib, re
import numpy as np
import numpy.ma as ma
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import rasterio
import torch
import yaml

from sklearn import metrics
from skimage import transform as trans
from pathlib import Path
from collections.abc import Sequence
from datetime import datetime, timedelta
from scipy.ndimage import rotate
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import init
from torch import optim
from torch.optim.lr_scheduler import _LRScheduler
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.tensorboard import SummaryWriter

from IPython.core.debugger import set_trace

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# The code cell is used to add the src directory to the Python path, making 
# it possible to import modules from that directory. 

module_path = os.path.abspath(os.path.join('../src'))
sys.path.insert(0, module_path)

# %%
from custom_dataset import CropData
from models.unet import Unet
from model_compiler import ModelCompiler
from custom_loss_functions import *
from utils import *

# %%
# The code cell loads a configuration file (default_config.yaml) using the YAML library and stores the 
# configuration data in the config dictionary. Then, it processes the global_stats section of the config 
# dictionary by expanding the lists for each stats based on the number of available time points. 
# As you can see we decided to generate a single set of normalization statistics and use it to 
# normalize all the time-points.

yaml_config_path = "/home/workdir/config/kenya-config.yaml"  # replace this path to your own config file.
num_time_points = 1  # Change this number accordingly if you use a dataset with a different temporal length.

with open(yaml_config_path, 'r') as file:
    config = yaml.load(file, Loader=yaml.SafeLoader)

# Perform multiplication and concatenation for each key in global_stats
for key, value in config['global_stats'].items():
    config['global_stats'][key] = value * num_time_points

# %%
# OPTIONAL
# pretty-print the config dictionary

import pprint
pprint.pprint(config, width=100, compact=True)
# Out:
# {'LR': 0.011,
#  'LR_policy': 'PolynomialLR',
#  'apply_normalization': False,
#  'aug_params': {'crop_size': '(224, 224)'},
#  'checkpoint_interval': 20,
#  'class_mapping': {0: 'Unknown',
#                    1: 'Building Footprint',
#                    2: 'Field Boundary',
#                    3: 'Building Within Field Boundary',
#                    4: 'Invalid'},
#  'criterion': {'gamma': 0.9, 'ignore_index': 0, 'name': 'TverskyFocalLoss', 'weight': None},
#  'epochs': 100,
#  'filter_config': [64, 128, 256, 512, 1024, 1024],
#  'freeze_params': None,
#  'global_stats': {'max': [255.0, 255.0, 255.0, 255.0],
#                   'mean': [112.1533, 114.1895, 92.9912, 254.9901],
#                   'min': [0.0, 0.0, 0.0, 0.0],
#                   'std': [39.2668, 34.4827, 34.6238, 1.5245]},
#  'gpuDevices': [0],
#  'init_type': 'kaiming',
#  'input_channels': 4,
#  'lr_prams': {'base_lr': 3e-05,
#               'factor': 0.8,
#               'gamma': 0.98,
#               'max_decay_steps': 80,
#               'max_lr': 0.01,
#               'milestones': [5, 10, 20, 35, 50, 70, 90],
#               'min_learning_rate': 0.0001,
#               'min_lr': 3e-06,
#               'mode': 'triangular',
#               'patience': 3,
#               'power': 0.85,
#               'step_size': 3,
#               'step_size_up': 1100,
#               'threshold': 0.0001,
#               'threshold_mode': 'rel'},
#  'momentum': 0.95,
#  'n_classes': 5,
#  'normal_strategy': 'z_value',
#  'optimizer': 'sam',
#  'out_dir': 'kenya_output',
#  'params_init': None,
#  'resume': False,
#  'resume_epoch': None,
#  'src_dir': '/home/data',
#  'stat_procedure': 'gpb',
#  'test_csv_path': '/home/workdir/test_ids.csv',
#  'train_BatchSize': 4,
#  'train_csv_path': '/home/workdir/train_ids.csv',
#  'train_dataset_name': 'kenya',
#  'train_dropout_rate': 0.15,
#  'transformations': ['random_crop'],
#  'use_skipAtt': False,
#  'val_csv_path': '/home/workdir/validate_ids.csv',
#  'val_metric_fname': 'validate_metrics_global_z_gpb.csv',
#  'val_test_BatchSize': 4,
#  'working_dir': '/home/workdir'}

# %% [markdown]
# ### Steps for training and finetuning

# %%
# STEP 1-1: Data Preparation and Loading
# This code cell reads the input dataset for training, pre-processes it, and creates a 'torch.utils.Dataset' 
# object to be used in the model training process. It utilizes the 'CropData' class from the custom module 
# (CropData.py) to achieve this.

train_dataset = CropData(src_dir=config["src_dir"],
                         usage="train",
                         dataset_name=config["train_dataset_name"],
                         csv_path=config["train_csv_path"],
                         apply_normalization=config["apply_normalization"],
                         normal_strategy=config["normal_strategy"],
                         stat_procedure=config["stat_procedure"],
                         global_stats=config["global_stats"],
                         trans=None, 
                         **config["aug_params"])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1451/1451 [00:09<00:00, 155.59it/s]
# ------ train dataset with 1451 patches created ------

# %%
# OPTIONAL
from utils import *
show_random_patches(train_dataset, sample_num=1, rgb_bands=(0, 1, 2))

# %%
# OPTIONAL
# Check the distribution of categories in a dataset
labels_count = get_labels_distribution(train_dataset, num_classes=5, ignore_class=None)
plot_labels_distribution(labels_count, num_classes=5, ignore_class=None)

# %%
# STEP 1-2: Data Batching and Device Assignment
# This code cell batchifies the training dataset using the 'DataLoader' class from PyTorch. The 'DataLoader' 
# efficiently loads the 'train_dataset' in batches, facilitating memory management during training.

train_loader = DataLoader(train_dataset,
                          batch_size=config["train_BatchSize"], 
                          shuffle=True)

# %%
# STEP 1-3
# Read the input dataset for validation, pre-process it and generate a 'torch.utils.Dataset' object 
# that can be accepted to get loaded into the model.

val_dataset = CropData(src_dir=config["src_dir"],
                       usage="validation",
                       dataset_name=config["train_dataset_name"],
                       csv_path=config["val_csv_path"],
                       apply_normalization=config["apply_normalization"],
                       normal_strategy=config["normal_strategy"],
                       stat_procedure=config["stat_procedure"],
                       global_stats=config["global_stats"],)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 414/414 [00:02<00:00, 154.35it/s]
# ------ validation dataset with 414 patches created ------

# %%
# OPTIONAL
# Check the distribution of categories in a dataset
labels_count = get_labels_distribution(val_dataset, num_classes=4, ignore_class=4)
plot_labels_distribution(labels_count, num_classes=4, ignore_class=None)

# %%
# STEP 1-4
# Batchify the validation dataset and put it on the defined 'Device'.

val_loader = DataLoader(val_dataset, 
                        batch_size=config["val_test_BatchSize"], 
                        shuffle=False)

# %%
# STEP 2: Model Initialization
# The model is based on the U-Net architecture, a popular choice for image segmentation tasks. 

model = Unet(n_classes=config["n_classes"], 
             in_channels=config["input_channels"], 
             use_skipAtt=config["use_skipAtt"],
             filter_config=config["filter_config"],
             dropout_rate=config["train_dropout_rate"])

# %%
# STEP 3: Model Compilation and Training Setup
# This code cell compiles the deep learning model, making it ready for training and evaluation. The 'ModelCompiler' 
# class is employed for this purpose, which offers a set of essential functionalities, such as model training 
# ('fit'), model saving, accuracy evaluation ('accuracy_evaluation'), inference ('inference'), and checkpointing 
# with resume capabilities. Additionally, it generates tensorboard reports and graphs for monitoring the training 
# process.

# Note: For training from scratch pass the "params_init" and "freeze_params" as None which results in loading a vanilla
# model with random initialization based on the "model_init_type" parameter. For training with warmup, only change the
# "params_init" to the path to model's saved parameter (not a checkpoint). For fine-tuning, change the "params_init" to 
# the path to model's saved parameter (by default its in the chckpt folder in working directory) and pass a list of integers
# representing the index of layers to be frozen.

compiled_model = ModelCompiler(model,
                               working_dir=config["working_dir"],
                               out_dir=config["out_dir"],
                               num_classes=config["n_classes"],
                               inch=config["input_channels"],
                               class_mapping=config["class_mapping"],
                               gpu_devices=[1],
                               model_init_type=config["init_type"], 
                               params_init='/home/workdir/kenya_output/Unet_ep100/chkpt/20_checkpoint.pth.tar',
                               freeze_params=config["freeze_params"])
# Out:
# ----------GPU available----------
# total number of trainable parameters: 103.4M
# ---------- Pre-trained model compiled successfully ----------

# %%
# STEP 4: Model Training and Validation
# This code cell trains and validates the compiled deep learning model for the specified number of epochs. 
# The model is trained using the "fit" method provided by the 'compiled_model' object. The training data 
# is obtained from 'train_loader', which contains batched samples and labels. Additionally, the 'val_loader' 
# is used for model validation during training. For each epoch the model reports the average loss value for both 
# training and validation phases, providing insights into its generalization capabilities.

# During the training the "fit" method will create a folder called 'chkpt' inside your working directory
# and save the checkpoints in user-defined intervals in that folder.
# Note: In case the training process is interrupted, you can change the "resume" argument and pass in the
# epoch to resume based on the created checkpoints.

criterion_name = config['criterion']['name']
weight = config['criterion']['weight']
ignore_index = config['criterion']['ignore_index']
gamma = config['criterion']['gamma']

if criterion_name == 'TverskyFocalLoss':
    criterion = TverskyFocalLoss(weight=weight, ignore_index=ignore_index, gamma=gamma)
else:
    criterion = nn.CrossEntropyLoss(weight=weight, ignore_index=ignore_index)
    

compiled_model.fit(train_loader,
                   val_loader, 
                   epochs=config["epochs"], 
                   optimizer_name=config["optimizer"], 
                   lr_init=config["LR"],
                   lr_policy=config["LR_policy"], 
                   criterion=criterion, 
                   momentum=config["momentum"],
                   checkpoint_interval=config["checkpoint_interval"],
                   resume=config["resume"],
                   resume_epoch=config["resume_epoch"],
                   **config["lr_prams"])
# Out:
# -------------------------- Start training --------------------------
# Epoch [1/100]
# train loss:0.5315549237340607
# validation loss: 0.5164
# LR: 0.01088407840200658
# time: 502
# Epoch [2/100]
# train loss:0.5042617533653564
# validation loss: 0.5092
# LR: 0.01088407840200658
# time: 502
# Epoch [3/100]
# train loss:0.31668753442726516
# validation loss: 0.1411
# LR: 0.01076793648428988
# time: 501
# Epoch [4/100]
# train loss:0.14274905630215468
# validation loss: 0.1353
# LR: 0.010651570995243713
# time: 502
# Epoch [5/100]
# train loss:0.13935408985996542
# validation loss: 0.1432
# LR: 0.010534978592374402
# time: 501
# Epoch [6/100]
# train loss:0.13680611009460672
# validation loss: 0.1396
# LR: 0.010418155838529623
# time: 502
# Epoch [7/100]
# train loss:0.13474148857733106
# validation loss: 0.1302
# LR: 0.0103010991979183
# time: 501
# Epoch [8/100]
# train loss:0.1340393022564817
# validation loss: 0.1266
# LR: 0.010183805031907068
# time: 501
# Epoch [9/100]
# train loss:0.12968942898610406
# validation loss: 0.1289
# LR: 0.010066269594577452
# time: 501
# Epoch [10/100]
# train loss:0.13145085531684567
# validation loss: 0.1236
# LR: 0.009948489028026699
# time: 501
# Epoch [11/100]
# train loss:0.1270445406939783
# validation loss: 0.1292
# LR: 0.009830459357393576
# time: 501
# Epoch [12/100]
# train loss:0.1324622379641559
# validation loss: 0.1286
# LR: 0.00971217648558892
# time: 501
# Epoch [13/100]
# train loss:0.12809715281463852
# validation loss: 0.1296
# LR: 0.009593636187708865
# time: 501
# Epoch [14/100]
# train loss:0.12947519193852408
# validation loss: 0.1213
# LR: 0.009474834105106671
# time: 501
# Epoch [15/100]
# train loss:0.1261787383942852
# validation loss: 0.1240
# LR: 0.009355765739096885
# time: 501
# Epoch [16/100]
# train loss:0.1268366872905125
# validation loss: 0.1246
# LR: 0.009236426444263108
# time: 501
# Epoch [17/100]
# train loss:0.12439181018343642
# validation loss: 0.1190
# LR: 0.009116811421337918
# time: 502
# Epoch [18/100]
# train loss:0.12410185812939133
# validation loss: 0.1247
# LR: 0.008996915709620482
# time: 501
# Epoch [19/100]
# train loss:0.12314196748879659
# validation loss: 0.1310
# LR: 0.008876734178893973
# time: 501
# Epoch [20/100]
# train loss:0.12440992839962818
# validation loss: 0.1200
# LR: 0.008756261520801238
# time: 501
# Epoch [21/100]
# train loss:0.13094697682027892
# validation loss: 0.1400
# LR: 0.008635492239632885
# time: 501
# Epoch [22/100]
# train loss:0.1389375263825059
# validation loss: 0.1338
# LR: 0.008514420642477247
# time: 501
# Epoch [23/100]
# train loss:0.1324154657232203
# validation loss: 0.1296
# LR: 0.008393040828676514
# time: 501
# Epoch [24/100]
# train loss:0.1270871303344438
# validation loss: 0.1308
# LR: 0.008271346678527249
# time: 501
# Epoch [25/100]
# train loss:0.13017278557166087
# validation loss: 0.1248
# LR: 0.008149331841156956
# time: 501
# Epoch [26/100]
# train loss:0.12670526198385998
# validation loss: 0.1269
# LR: 0.008026989721500798
# time: 501
# Epoch [27/100]
# train loss:0.12802306872589858
# validation loss: 0.1243
# LR: 0.00790431346629404
# time: 501
# Epoch [28/100]
# train loss:0.12357198923939106
# validation loss: 0.1233
# LR: 0.0077812959489862174
# time: 501
# Epoch [29/100]
# train loss:0.12480340326415278
# validation loss: 0.1276
# LR: 0.007657929753472054
# time: 501
# Epoch [30/100]

# %%
# STEP 5
# Same model parameters
compiled_model.save(save_object="params")

# %%
# STEP 6
# Generate the accuracy metrics.
metrics = compiled_model.accuracy_evaluation(val_loader, filename=config["val_metric_fname"])
# Out:
# ---------------- Start evaluation ----------------
# /home/workdir/src/accuracy_metric.py:63: RuntimeWarning: invalid value encountered in true_divide
#   2 * (precision * recall) / (precision + recall),
# ---------------- Evaluation finished in 27s ----------------

# %% [markdown]
# ### Steps for prediction

# %%
test_dataset = CropData(src_dir=config["src_dir"],
                       usage="inference",
                       dataset_name=config["train_dataset_name"],
                       csv_path=config["test_csv_path"],
                       apply_normalization=config["apply_normalization"],
                       normal_strategy=config["normal_strategy"],
                       stat_procedure=config["stat_procedure"],
                       global_stats=config["global_stats"],)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 209/209 [00:01<00:00, 157.21it/s]
# ------ inference dataset with 209 patches created ------

# %%
def meta_handling_collate_fn(batch):
    images = []
    labels = []
    img_ids = []
    img_metas = []

    # Unpack elements from each sample in the batch
    for sample in batch:
        images.append(sample[0])
        labels.append(sample[1])
        img_ids.append(sample[2])
        img_metas.append(sample[3])  # append the dict to the list

    # Stack images and labels into a single tensor
    images = torch.stack(images, dim=0)
    labels = torch.stack(labels, dim=0)
    
    return images, labels, img_ids, img_metas


test_loader = DataLoader(test_dataset, 
                        batch_size=config["val_test_BatchSize"], 
                        shuffle=False,
                        collate_fn=meta_handling_collate_fn)

# %%
model = Unet(n_classes=config["n_classes"], 
             in_channels=config["input_channels"], 
             use_skipAtt=config["use_skipAtt"],
             filter_config=config["filter_config"],
             dropout_rate=config["train_dropout_rate"])

# %%
compiled_model = ModelCompiler(model,
                               working_dir=config["working_dir"],
                               out_dir=config["out_dir"],
                               num_classes=config["n_classes"],
                               inch=config["input_channels"],
                               class_mapping=config["class_mapping"],
                               gpu_devices=[1],
                               model_init_type=config["init_type"], 
                               params_init='/home/workdir/kenya_output/Unet_ep100/chkpt/20_checkpoint.pth.tar',
                               freeze_params=config["freeze_params"])
# Out:
# ----------GPU available----------
# total number of trainable parameters: 103.4M
# ---------- Pre-trained model compiled successfully ----------

# %%
compiled_model.inference(test_loader, out_dir=config["out_dir"])
# Out:
# ---------------- Start prediction ----------------
# Pred tile: kenol1_1000 is written to kenya_output
# Pred tile: kenol1_1010 is written to kenya_output
# Pred tile: kenol1_1013 is written to kenya_output
# Pred tile: kenol1_1019 is written to kenya_output
# Pred tile: kenol1_1072 is written to kenya_output
# Pred tile: kenol1_1073 is written to kenya_output
# Pred tile: kenol1_1081 is written to kenya_output
# Pred tile: kenol1_1088 is written to kenya_output
# Pred tile: kenol1_1102 is written to kenya_output
# Pred tile: kenol1_1103 is written to kenya_output
# Pred tile: kenol1_1154 is written to kenya_output
# Pred tile: kenol1_1159 is written to kenya_output
# Pred tile: kenol1_1161 is written to kenya_output
# Pred tile: kenol1_1167 is written to kenya_output
# Pred tile: kenol1_1172 is written to kenya_output
# Pred tile: kenol1_1179 is written to kenya_output
# Pred tile: kenol1_1260 is written to kenya_output
# Pred tile: kenol1_1262 is written to kenya_output
# Pred tile: kenol1_1263 is written to kenya_output
# Pred tile: kenol1_1275 is written to kenya_output
# Pred tile: kenol1_1321 is written to kenya_output
# Pred tile: kenol1_1327 is written to kenya_output
# Pred tile: kenol1_1347 is written to kenya_output
# Pred tile: kenol1_1401 is written to kenya_output
# Pred tile: kenol1_1409 is written to kenya_output
# Pred tile: kenol1_1411 is written to kenya_output
# Pred tile: kenol1_1433 is written to kenya_output
# Pred tile: kenol1_1437 is written to kenya_output
# Pred tile: kenol1_1443 is written to kenya_output
# Pred tile: kenol1_1448 is written to kenya_output
# Pred tile: kenol1_1450 is written to kenya_output
# Pred tile: kenol1_1491 is written to kenya_output
# Pred tile: kenol1_1492 is written to kenya_output
# Pred tile: kenol1_1509 is written to kenya_output
# Pred tile: kenol1_1516 is written to kenya_output
# Pred tile: kenol1_1523 is written to kenya_output
# Pred tile: kenol1_1530 is written to kenya_output
# Pred tile: kenol1_1567 is written to kenya_output
# Pred tile: kenol1_1570 is written to kenya_output
# Pred tile: kenol1_1584 is written to kenya_output
# Pred tile: kenol1_1588 is written to kenya_output
# Pred tile: kenol1_1590 is written to kenya_output
# Pred tile: kenol1_1592 is written to kenya_output
# Pred tile: kenol1_1605 is written to kenya_output
# Pred tile: kenol1_1610 is written to kenya_output
# Pred tile: kenol1_1649 is written to kenya_output
# Pred tile: kenol1_1670 is written to kenya_output
# Pred tile: kenol1_1682 is written to kenya_output
# Pred tile: kenol1_1687 is written to kenya_output
# Pred tile: kenol1_1699 is written to kenya_output
# Pred tile: kenol1_1743 is written to kenya_output
# Pred tile: kenol1_1750 is written to kenya_output
# Pred tile: kenol1_1765 is written to kenya_output
# Pred tile: kenol1_1789 is written to kenya_output
# Pred tile: kenol1_1790 is written to kenya_output
# Pred tile: kenol1_1791 is written to kenya_output
# Pred tile: kenol1_1792 is written to kenya_output
# Pred tile: kenol1_1795 is written to kenya_output
# Pred tile: kenol1_1829 is written to kenya_output
# Pred tile: kenol1_1841 is written to kenya_output
# Pred tile: kenol1_1846 is written to kenya_output
# Pred tile: kenol1_1855 is written to kenya_output
# Pred tile: kenol1_1856 is written to kenya_output
# Pred tile: kenol1_1861 is written to kenya_output
# Pred tile: kenol1_1882 is written to kenya_output
# Pred tile: kenol1_1911 is written to kenya_output
# Pred tile: kenol1_1914 is written to kenya_output
# Pred tile: kenol1_1917 is written to kenya_output
# Pred tile: kenol1_1928 is written to kenya_output
# Pred tile: kenol1_1934 is written to kenya_output
# Pred tile: kenol1_1963 is written to kenya_output
# Pred tile: kenol1_1968 is written to kenya_output
# Pred tile: kenol1_1990 is written to kenya_output
# Pred tile: kenol1_1998 is written to kenya_output
# Pred tile: kenol1_2007 is written to kenya_output
# Pred tile: kenol1_2030 is written to kenya_output
# Pred tile: kenol1_2040 is written to kenya_output
# Pred tile: kenol1_2043 is written to kenya_output
# Pred tile: kenol1_2045 is written to kenya_output
# Pred tile: kenol1_2046 is written to kenya_output
# Pred tile: kenol1_2078 is written to kenya_output
# Pred tile: kenol1_2087 is written to kenya_output
# Pred tile: kenol1_2098 is written to kenya_output
# Pred tile: kenol1_2115 is written to kenya_output
# Pred tile: kenol1_2177 is written to kenya_output
# Pred tile: kenol1_2188 is written to kenya_output
# Pred tile: kenol1_2194 is written to kenya_output
# Pred tile: kenol1_2198 is written to kenya_output
# Pred tile: kenol1_2205 is written to kenya_output
# Pred tile: kenol1_2260 is written to kenya_output
# Pred tile: kenol1_2277 is written to kenya_output
# Pred tile: kenol1_2283 is written to kenya_output
# Pred tile: kenol1_241 is written to kenya_output
# Pred tile: kenol1_484 is written to kenya_output
# Pred tile: kenol1_490 is written to kenya_output
# Pred tile: kenol1_492 is written to kenya_output
# Pred tile: kenol1_497 is written to kenya_output
# Pred tile: kenol1_656 is written to kenya_output
# Pred tile: kenol1_657 is written to kenya_output
# Pred tile: kenol1_659 is written to kenya_output
# Pred tile: kenol1_661 is written to kenya_output
# Pred tile: kenol1_667 is written to kenya_output
# Pred tile: kenol1_668 is written to kenya_output
# Pred tile: kenol1_671 is written to kenya_output
# Pred tile: kenol1_747 is written to kenya_output
# Pred tile: kenol1_749 is written to kenya_output
# Pred tile: kenol1_751 is written to kenya_output
# Pred tile: kenol1_836 is written to kenya_output
# Pred tile: kenol1_842 is written to kenya_output
# Pred tile: kenol1_898 is written to kenya_output
# Pred tile: kenol1_922 is written to kenya_output
# Pred tile: kenol1_923 is written to kenya_output
# Pred tile: kenol1_930 is written to kenya_output
# Pred tile: kenol1_990 is written to kenya_output
# Pred tile: kenol1_996 is written to kenya_output
# Pred tile: kenol1_997 is written to kenya_output
# Pred tile: kenol2_1024 is written to kenya_output
# Pred tile: kenol2_1033 is written to kenya_output
# Pred tile: kenol2_1045 is written to kenya_output
# Pred tile: kenol2_1046 is written to kenya_output
# Pred tile: kenol2_1053 is written to kenya_output
# Pred tile: kenol2_1070 is written to kenya_output
# Pred tile: kenol2_1091 is written to kenya_output
# Pred tile: kenol2_1092 is written to kenya_output
# Pred tile: kenol2_1111 is written to kenya_output
# Pred tile: kenol2_1115 is written to kenya_output
# Pred tile: kenol2_1117 is written to kenya_output
# Pred tile: kenol2_1122 is written to kenya_output
# Pred tile: kenol2_1137 is written to kenya_output
# Pred tile: kenol2_1141 is written to kenya_output
# Pred tile: kenol2_1177 is written to kenya_output
# Pred tile: kenol2_1185 is written to kenya_output
# Pred tile: kenol2_1190 is written to kenya_output
# Pred tile: kenol2_1215 is written to kenya_output
# Pred tile: kenol2_1225 is written to kenya_output
# Pred tile: kenol2_1248 is written to kenya_output
# Pred tile: kenol2_1259 is written to kenya_output
# Pred tile: kenol2_1267 is written to kenya_output
# Pred tile: kenol2_1278 is written to kenya_output
# Pred tile: kenol2_1279 is written to kenya_output
# Pred tile: kenol2_1294 is written to kenya_output
# Pred tile: kenol2_1298 is written to kenya_output
# Pred tile: kenol2_1301 is written to kenya_output
# Pred tile: kenol2_1317 is written to kenya_output
# Pred tile: kenol2_1335 is written to kenya_output
# Pred tile: kenol2_1346 is written to kenya_output
# Pred tile: kenol2_1353 is written to kenya_output
# Pred tile: kenol2_1375 is written to kenya_output
# Pred tile: kenol2_1406 is written to kenya_output
# Pred tile: kenol2_1410 is written to kenya_output
# Pred tile: kenol2_1429 is written to kenya_output
# Pred tile: kenol2_1434 is written to kenya_output
# Pred tile: kenol2_1449 is written to kenya_output
# Pred tile: kenol2_1453 is written to kenya_output
# Pred tile: kenol2_1475 is written to kenya_output
# Pred tile: kenol2_1476 is written to kenya_output
# Pred tile: kenol2_1479 is written to kenya_output
# Pred tile: kenol2_1481 is written to kenya_output
# Pred tile: kenol2_1482 is written to kenya_output
# Pred tile: kenol2_1513 is written to kenya_output
# Pred tile: kenol2_1523 is written to kenya_output
# Pred tile: kenol2_1526 is written to kenya_output
# Pred tile: kenol2_1551 is written to kenya_output
# Pred tile: kenol2_1558 is written to kenya_output
# Pred tile: kenol2_1560 is written to kenya_output
# Pred tile: kenol2_1561 is written to kenya_output
# Pred tile: kenol2_1580 is written to kenya_output
# Pred tile: kenol2_1591 is written to kenya_output
# Pred tile: kenol2_1631 is written to kenya_output
# Pred tile: kenol2_1651 is written to kenya_output
# Pred tile: kenol2_1663 is written to kenya_output
# Pred tile: kenol2_1685 is written to kenya_output
# Pred tile: kenol2_1686 is written to kenya_output
# Pred tile: kenol2_1718 is written to kenya_output
# Pred tile: kenol2_1720 is written to kenya_output
# Pred tile: kenol2_364 is written to kenya_output
# Pred tile: kenol2_375 is written to kenya_output
# Pred tile: kenol2_453 is written to kenya_output
# Pred tile: kenol2_519 is written to kenya_output
# Pred tile: kenol2_527 is written to kenya_output
# Pred tile: kenol2_531 is written to kenya_output
# Pred tile: kenol2_578 is written to kenya_output
# Pred tile: kenol2_579 is written to kenya_output
# Pred tile: kenol2_665 is written to kenya_output
# Pred tile: kenol2_727 is written to kenya_output
# Pred tile: kenol2_747 is written to kenya_output
# Pred tile: kenol2_763 is written to kenya_output
# Pred tile: kenol2_799 is written to kenya_output
# Pred tile: kenol2_803 is written to kenya_output
# Pred tile: kenol2_804 is written to kenya_output
# Pred tile: kenol2_808 is written to kenya_output
# Pred tile: kenol2_812 is written to kenya_output
# Pred tile: kenol2_816 is written to kenya_output
# Pred tile: kenol2_827 is written to kenya_output
# Pred tile: kenol2_839 is written to kenya_output
# Pred tile: kenol2_841 is written to kenya_output
# Pred tile: kenol2_870 is written to kenya_output
# Pred tile: kenol2_876 is written to kenya_output
# Pred tile: kenol2_893 is written to kenya_output
# Pred tile: kenol2_895 is written to kenya_output
# Pred tile: kenol2_901 is written to kenya_output
# Pred tile: kenol2_904 is written to kenya_output
# Pred tile: kenol2_918 is written to kenya_output
# Pred tile: kenol2_944 is written to kenya_output
# Pred tile: kenol2_946 is written to kenya_output
# Pred tile: kenol2_952 is written to kenya_output
# Pred tile: kenol2_962 is written to kenya_output
# Pred tile: kenol2_964 is written to kenya_output
# Pred tile: kenol2_986 is written to kenya_output
# ---------------- Prediction finished in 15s ----------------
