# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
import os, sys, copy, time, math, random, numbers, itertools, tqdm, importlib, re
import numpy as np
import numpy.ma as ma
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import rasterio
import torch
import yaml

from sklearn import metrics
from skimage import transform as trans
from pathlib import Path
from collections.abc import Sequence
from datetime import datetime, timedelta
from scipy.ndimage import rotate
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import init
from torch import optim
from torch.optim.lr_scheduler import _LRScheduler
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.tensorboard import SummaryWriter

from IPython.core.debugger import set_trace

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# The code cell is used to add the src directory to the Python path, making 
# it possible to import modules from that directory. 

module_path = os.path.abspath(os.path.join('../src'))
sys.path.insert(0, module_path)

# %%
from custom_dataset import CropData
from models.unet import Unet
from model_compiler import ModelCompiler
from custom_loss_functions import *
from utils import *

# %%
# The code cell loads a configuration file (default_config.yaml) using the YAML library and stores the 
# configuration data in the config dictionary. Then, it processes the global_stats section of the config 
# dictionary by expanding the lists for each stats based on the number of available time points. 
# As you can see we decided to generate a single set of normalization statistics and use it to 
# normalize all the time-points.

yaml_config_path = "/home/workdir/config/kenya-config-sam.yaml"  # replace this path to your own config file.
num_time_points = 1  # Change this number accordingly if you use a dataset with a different temporal length.

with open(yaml_config_path, 'r') as file:
    config = yaml.load(file, Loader=yaml.SafeLoader)

# Perform multiplication and concatenation for each key in global_stats
for key, value in config['global_stats'].items():
    config['global_stats'][key] = value * num_time_points

# %%
# OPTIONAL
# pretty-print the config dictionary

import pprint
pprint.pprint(config, width=100, compact=True)
# Out:
# {'LR': 0.011,
#  'LR_policy': 'PolynomialLR',
#  'apply_normalization': True,
#  'aug_params': {'rotation_degree': '(-90, 90)'},
#  'checkpoint_interval': 20,
#  'class_mapping': {0: 'Unknown', 1: 'Building Footprint', 2: 'Field Boundary'},
#  'criterion': {'gamma': 0.9, 'ignore_index': -1, 'name': 'TverskyFocalLoss', 'weight': None},
#  'epochs': 100,
#  'filter_config': [64, 128, 256, 512, 1024, 1024],
#  'freeze_params': None,
#  'global_stats': {'max': [255.0, 255.0, 255.0, 255.0],
#                   'mean': [112.1533, 114.1895, 92.9912, 0],
#                   'min': [0.0, 0.0, 0.0, 0.0],
#                   'std': [39.2668, 34.4827, 34.6238, 1]},
#  'gpuDevices': [0],
#  'init_type': 'kaiming',
#  'input_channels': 4,
#  'lr_prams': {'base_lr': 3e-05,
#               'factor': 0.8,
#               'gamma': 0.98,
#               'max_decay_steps': 80,
#               'max_lr': 0.01,
#               'milestones': [5, 10, 20, 35, 50, 70, 90],
#               'min_learning_rate': 0.0001,
#               'min_lr': 3e-06,
#               'mode': 'triangular',
#               'patience': 3,
#               'power': 0.85,
#               'step_size': 3,
#               'step_size_up': 1100,
#               'threshold': 0.0001,
#               'threshold_mode': 'rel'},
#  'momentum': 0.95,
#  'n_classes': 3,
#  'normal_strategy': 'z_value',
#  'optimizer': 'sam',
#  'out_dir': 'kenya_output_reclass',
#  'params_init': None,
#  'resume': None,
#  'resume_epoch': None,
#  'src_dir': '/home/data',
#  'stat_procedure': 'gpb',
#  'test_csv_path': '/home/workdir/test_ids.csv',
#  'train_BatchSize': 4,
#  'train_csv_path': '/home/workdir/train_ids.csv',
#  'train_dataset_name': 'kenya-sam',
#  'train_dropout_rate': 0.15,
#  'transformations': ['v_flip', 'h_flip', 'd_flip'],
#  'use_skipAtt': False,
#  'val_csv_path': '/home/workdir/validate_ids.csv',
#  'val_metric_fname': 'validate_metrics_kenya_sam.csv',
#  'val_test_BatchSize': 4,
#  'working_dir': '/home/workdir'}

# %% [markdown]
# ### Steps for training and finetuning

# %%
# STEP 1-1: Data Preparation and Loading
# This code cell reads the input dataset for training, pre-processes it, and creates a 'torch.utils.Dataset' 
# object to be used in the model training process. It utilizes the 'CropData' class from the custom module 
# (CropData.py) to achieve this.

train_dataset = CropData(src_dir=config["src_dir"],
                         usage="train",
                         dataset_name=config["train_dataset_name"],
                         csv_path=config["train_csv_path"],
                         apply_normalization=config["apply_normalization"],
                         normal_strategy=config["normal_strategy"],
                         stat_procedure=config["stat_procedure"],
                         global_stats=config["global_stats"],
                         trans=config["transformations"], 
                         **config["aug_params"])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1428/1428 [00:27<00:00, 51.95it/s]
# ------ train dataset with 1428 patches created ------

# %%
# OPTIONAL
show_random_patches(train_dataset, sample_num=5, rgb_bands=(0, 1, 2))

# %%
# OPTIONAL
# Check the distribution of categories in a dataset
labels_count = get_labels_distribution(train_dataset, num_classes=3, ignore_class=None)
plot_labels_distribution(labels_count, num_classes=3, ignore_class=None)

# %%
# STEP 1-2: Data Batching and Device Assignment
# This code cell batchifies the training dataset using the 'DataLoader' class from PyTorch. The 'DataLoader' 
# efficiently loads the 'train_dataset' in batches, facilitating memory management during training.

train_loader = DataLoader(train_dataset,
                          batch_size=config["train_BatchSize"], 
                          shuffle=True)

# %%
# STEP 1-3
# Read the input dataset for validation, pre-process it and generate a 'torch.utils.Dataset' object 
# that can be accepted to get loaded into the model.

val_dataset = CropData(src_dir=config["src_dir"],
                       usage="validation",
                       dataset_name=config["train_dataset_name"],
                       csv_path=config["val_csv_path"],
                       apply_normalization=config["apply_normalization"],
                       normal_strategy=config["normal_strategy"],
                       stat_procedure=config["stat_procedure"],
                       global_stats=config["global_stats"],)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 408/408 [00:08<00:00, 50.93it/s]
# ------ validation dataset with 408 patches created ------

# %%
# OPTIONAL
# Check the distribution of categories in a dataset
labels_count = get_labels_distribution(val_dataset, num_classes=3, ignore_class=None)
plot_labels_distribution(labels_count, num_classes=3, ignore_class=None)

# %%
# STEP 1-4
# Batchify the validation dataset and put it on the defined 'Device'.

val_loader = DataLoader(val_dataset, 
                        batch_size=config["val_test_BatchSize"], 
                        shuffle=False)

# %%
# STEP 2: Model Initialization
# The model is based on the U-Net architecture, a popular choice for image segmentation tasks. 

model = Unet(n_classes=config["n_classes"], 
             in_channels=config["input_channels"], 
             use_skipAtt=config["use_skipAtt"],
             filter_config=config["filter_config"],
             dropout_rate=config["train_dropout_rate"])

# %%
# STEP 3: Model Compilation and Training Setup
# This code cell compiles the deep learning model, making it ready for training and evaluation. The 'ModelCompiler' 
# class is employed for this purpose, which offers a set of essential functionalities, such as model training 
# ('fit'), model saving, accuracy evaluation ('accuracy_evaluation'), inference ('inference'), and checkpointing 
# with resume capabilities. Additionally, it generates tensorboard reports and graphs for monitoring the training 
# process.

# Note: For training from scratch pass the "params_init" and "freeze_params" as None which results in loading a vanilla
# model with random initialization based on the "model_init_type" parameter. For training with warmup, only change the
# "params_init" to the path to model's saved parameter (not a checkpoint). For fine-tuning, change the "params_init" to 
# the path to model's saved parameter (by default its in the chckpt folder in working directory) and pass a list of integers
# representing the index of layers to be frozen.

compiled_model = ModelCompiler(model,
                               working_dir=config["working_dir"],
                               out_dir=config["out_dir"],
                               num_classes=config["n_classes"],
                               inch=config["input_channels"],
                               class_mapping=config["class_mapping"],
                               gpu_devices=config["gpuDevices"],
                               model_init_type=config["init_type"], 
                               params_init=config["params_init"],
                               freeze_params=config["freeze_params"])
# Out:
# ----------GPU available----------
# initialize network with kaiming.
# total number of trainable parameters: 103.4M
# ---------- Vanilla Model compiled successfully ----------

# %%
# STEP 4: Model Training and Validation
# This code cell trains and validates the compiled deep learning model for the specified number of epochs. 
# The model is trained using the "fit" method provided by the 'compiled_model' object. The training data 
# is obtained from 'train_loader', which contains batched samples and labels. Additionally, the 'val_loader' 
# is used for model validation during training. For each epoch the model reports the average loss value for both 
# training and validation phases, providing insights into its generalization capabilities.

# During the training the "fit" method will create a folder called 'chkpt' inside your working directory
# and save the checkpoints in user-defined intervals in that folder.
# Note: In case the training process is interrupted, you can change the "resume" argument and pass in the
# epoch to resume based on the created checkpoints.

criterion_name = config['criterion']['name']
weight = config['criterion']['weight']
ignore_index = config['criterion']['ignore_index']
gamma = config['criterion']['gamma']

if criterion_name == 'TverskyFocalLoss':
    criterion = TverskyFocalLoss(weight=weight, ignore_index=ignore_index, gamma=gamma)
else:
    criterion = nn.CrossEntropyLoss(weight=weight, ignore_index=ignore_index)
    

compiled_model.fit(train_loader,
                   val_loader, 
                   epochs=config["epochs"], 
                   optimizer_name=config["optimizer"], 
                   lr_init=config["LR"],
                   lr_policy=config["LR_policy"], 
                   criterion=criterion, 
                   momentum=config["momentum"],
                   checkpoint_interval=config["checkpoint_interval"],
                   resume=config["resume"],
                   resume_epoch=config["resume_epoch"],
                   **config["lr_prams"])
# Out:
# -------------------------- Start training --------------------------
# Epoch [1/100]
# train loss:0.47676875811665
# validation loss: 0.4993
# LR: 0.01088407840200658
# time: 503
# Epoch [2/100]
# train loss:0.4489838103620278
# validation loss: 0.5839
# LR: 0.01088407840200658
# time: 498
# Epoch [3/100]
# train loss:0.41188281190161613
# validation loss: 0.5316
# LR: 0.01076793648428988
# time: 497
# Epoch [4/100]
# train loss:0.37989387462953894
# validation loss: 0.5343
# LR: 0.010651570995243713
# time: 499
# Epoch [5/100]
# train loss:0.37878221081418484
# validation loss: 0.4991
# LR: 0.010534978592374402
# time: 498
# Epoch [6/100]
# train loss:0.3661232679581442
# validation loss: 0.4488
# LR: 0.010418155838529623
# time: 499
# Epoch [7/100]
# train loss:0.36621486706560064
# validation loss: 0.3550
# LR: 0.0103010991979183
# time: 499
# Epoch [8/100]
# train loss:0.35655230559220835
# validation loss: 0.3568
# LR: 0.010183805031907068
# time: 499
# Epoch [9/100]
# train loss:0.35200297598745306
# validation loss: 0.3939
# LR: 0.010066269594577452
# time: 499
# Epoch [10/100]
# train loss:0.3361483863046189
# validation loss: 0.4373
# LR: 0.009948489028026699
# time: 498
# Epoch [11/100]
# train loss:0.340000630092888
# validation loss: 0.3642
# LR: 0.009830459357393576
# time: 499
# Epoch [12/100]
# train loss:0.31977170144392997
# validation loss: 0.3204
# LR: 0.00971217648558892
# time: 498
# Epoch [13/100]
# train loss:0.29920774437382774
# validation loss: 0.3549
# LR: 0.009593636187708865
# time: 498
# Epoch [14/100]
# train loss:0.2969515028746188
# validation loss: 0.3676
# LR: 0.009474834105106671
# time: 498
# Epoch [15/100]
# train loss:0.2845042901379721
# validation loss: 0.4072
# LR: 0.009355765739096885
# time: 498
# Epoch [16/100]
# train loss:0.28913807616430837
# validation loss: 0.3621
# LR: 0.009236426444263108
# time: 498
# Epoch [17/100]
# train loss:0.2680964797985654
# validation loss: 0.3276
# LR: 0.009116811421337918
# time: 498
# Epoch [18/100]
# train loss:0.26584002344297764
# validation loss: 0.2716
# LR: 0.008996915709620482
# time: 498
# Epoch [19/100]
# train loss:0.2652948092178804
# validation loss: 0.3152
# LR: 0.008876734178893973
# time: 498
# Epoch [20/100]
# train loss:0.2432009748676244
# validation loss: 0.2779
# LR: 0.008756261520801238
# time: 499
# Epoch [21/100]
# train loss:0.2472165265232742
# validation loss: 0.3959
# LR: 0.008635492239632885
# time: 499
# Epoch [22/100]
# train loss:0.2474679588770666
# validation loss: 0.2827
# LR: 0.008514420642477247
# time: 499
# Epoch [23/100]
# train loss:0.23595937228753788
# validation loss: 0.3048
# LR: 0.008393040828676514
# time: 498
# Epoch [24/100]
# train loss:0.23140167849821872
# validation loss: 0.2312
# LR: 0.008271346678527249
# time: 499
# Epoch [25/100]
# train loss:0.2368936356605769
# validation loss: 0.2499
# LR: 0.008149331841156956
# time: 498
# Epoch [26/100]
# train loss:0.2277291669231169
# validation loss: 0.2554
# LR: 0.008026989721500798
# time: 498
# Epoch [27/100]
# train loss:0.23327581670020475
# validation loss: 0.2830
# LR: 0.00790431346629404
# time: 499
# Epoch [28/100]
# train loss:0.21777039459523032
# validation loss: 0.2570
# LR: 0.0077812959489862174
# time: 500
# Epoch [29/100]
# train loss:0.21642818617052725
# validation loss: 0.2342
# LR: 0.007657929753472054
# time: 498
# Epoch [30/100]
# train loss:0.21048791482209825
# validation loss: 0.2646
# LR: 0.007534207156521739
# time: 498
# Epoch [31/100]
# train loss:0.20802910860721804
# validation loss: 0.2656
# LR: 0.007410120108778984
# time: 499
# Epoch [32/100]
# train loss:0.20566803725118063
# validation loss: 0.4001
# LR: 0.007285660214179062
# time: 498
# Epoch [33/100]

# %%
# STEP 5
# Same model parameters
compiled_model.save(save_object="params")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # STEP 5
#       2 # Same model parameters
# ----> 3 compiled_model.save(save_object="params")
#
# File /home/workdir/src/model_compiler.py:461, in ModelCompiler.save(self, save_object)
#     457         torch.save(self.model.module.state_dict(),
#     458                    os.path.join(self.checkpoint_dirpath, "{}_final_state.pth".format(self.model_name)))
#     459     else:
#     460         torch.save(self.model.state_dict(),
# --> 461                    os.path.join(self.checkpoint_dirpath, "{}_final_state.pth".format(self.model_name)))
#     463     print("--------------------- Model parameters is saved to disk ---------------------")
#     465 elif save_object == "model":
#
# File /opt/conda/lib/python3.10/posixpath.py:76, in join(a, *p)
#      71 def join(a, *p):
#      72     """Join two or more pathname components, inserting '/' as needed.
#      73     If any component is an absolute path, all previous path components
#      74     will be discarded.  An empty last part will result in a path that
#      75     ends with a separator."""
# ---> 76     a = os.fspath(a)
#      77     sep = _get_sep(a)
#      78     path = a
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
# STEP 6
# Generate the accuracy metrics.
metrics = compiled_model.accuracy_evaluation(val_loader, filename=config["val_metric_fname"])
# Out:
# ---------------- Start evaluation ----------------
# /home/workdir/src/accuracy_metric.py:36: RuntimeWarning: invalid value encountered in true_divide
#   tp / (tp + fp),
# /home/workdir/src/accuracy_metric.py:63: RuntimeWarning: invalid value encountered in true_divide
#   2 * (precision * recall) / (precision + recall),
# ---------------- Evaluation finished in 26s ----------------

# %%
# STEP 6
# Generate the accuracy metrics.
metrics = compiled_model.accuracy_evaluation(val_loader, filename=config["val_metric_fname"])
# Out:
# ---------------- Start evaluation ----------------
# ---------------- Evaluation finished in 26s ----------------

# %% [markdown]
# ### Steps for prediction

# %%
test_dataset = CropData(src_dir=config["src_dir"],
                       usage="inference",
                       dataset_name=config["train_dataset_name"],
                       csv_path=config["test_csv_path"],
                       apply_normalization=config["apply_normalization"],
                       normal_strategy=config["normal_strategy"],
                       stat_procedure=config["stat_procedure"],
                       global_stats=config["global_stats"],)
# Out:
# 100%|█████████████████████████████████████████████████████████| 205/205 [00:01<00:00, 110.68it/s]
# ------ inference dataset with 205 patches created ------

# %%
def meta_handling_collate_fn(batch):
    images = []
    labels = []
    img_ids = []
    img_metas = []

    # Unpack elements from each sample in the batch
    for sample in batch:
        images.append(sample[0])
        labels.append(sample[1])
        img_ids.append(sample[2])
        img_metas.append(sample[3])  # append the dict to the list

    # Stack images and labels into a single tensor
    images = torch.stack(images, dim=0)
    labels = torch.stack(labels, dim=0)
    
    return images, labels, img_ids, img_metas


test_loader = DataLoader(test_dataset, 
                        batch_size=config["val_test_BatchSize"], 
                        shuffle=False,
                        collate_fn=meta_handling_collate_fn)

# %%
model = Unet(n_classes=config["n_classes"], 
             in_channels=config["input_channels"], 
             use_skipAtt=config["use_skipAtt"],
             filter_config=config["filter_config"],
             dropout_rate=config["train_dropout_rate"])

# %%
compiled_model = ModelCompiler(model,
                               working_dir=config["working_dir"],
                               out_dir=config["out_dir"],
                               num_classes=config["n_classes"],
                               inch=config["input_channels"],
                               class_mapping=config["class_mapping"],
                               gpu_devices=config["gpuDevices"],
                               model_init_type=config["init_type"], 
                               params_init=config["params_init"],
                               freeze_params=config["freeze_params"])
# Out:
# ----------GPU available----------
# total number of trainable parameters: 103.4M
# ---------- Pre-trained model compiled successfully ----------

# %%
compiled_model.inference(test_loader, out_dir=config["out_dir"])
# Out:
# ---------------- Start prediction ----------------
# Pred tile: kenol1_1007 is written to kenya_output
# Pred tile: kenol1_1064 is written to kenya_output
# Pred tile: kenol1_1070 is written to kenya_output
# Pred tile: kenol1_1071 is written to kenya_output
# Pred tile: kenol1_1087 is written to kenya_output
# Pred tile: kenol1_1101 is written to kenya_output
# Pred tile: kenol1_1103 is written to kenya_output
# Pred tile: kenol1_1149 is written to kenya_output
# Pred tile: kenol1_1150 is written to kenya_output
# Pred tile: kenol1_1151 is written to kenya_output
# Pred tile: kenol1_1156 is written to kenya_output
# Pred tile: kenol1_1180 is written to kenya_output
# Pred tile: kenol1_1244 is written to kenya_output
# Pred tile: kenol1_1248 is written to kenya_output
# Pred tile: kenol1_1254 is written to kenya_output
# Pred tile: kenol1_1265 is written to kenya_output
# Pred tile: kenol1_1266 is written to kenya_output
# Pred tile: kenol1_1278 is written to kenya_output
# Pred tile: kenol1_1312 is written to kenya_output
# Pred tile: kenol1_1335 is written to kenya_output
# Pred tile: kenol1_1339 is written to kenya_output
# Pred tile: kenol1_1342 is written to kenya_output
# Pred tile: kenol1_1359 is written to kenya_output
# Pred tile: kenol1_1363 is written to kenya_output
# Pred tile: kenol1_1405 is written to kenya_output
# Pred tile: kenol1_1414 is written to kenya_output
# Pred tile: kenol1_1425 is written to kenya_output
# Pred tile: kenol1_1432 is written to kenya_output
# Pred tile: kenol1_1438 is written to kenya_output
# Pred tile: kenol1_1484 is written to kenya_output
# Pred tile: kenol1_1486 is written to kenya_output
# Pred tile: kenol1_1488 is written to kenya_output
# Pred tile: kenol1_1491 is written to kenya_output
# Pred tile: kenol1_1494 is written to kenya_output
# Pred tile: kenol1_1514 is written to kenya_output
# Pred tile: kenol1_1535 is written to kenya_output
# Pred tile: kenol1_1569 is written to kenya_output
# Pred tile: kenol1_1573 is written to kenya_output
# Pred tile: kenol1_1582 is written to kenya_output
# Pred tile: kenol1_1589 is written to kenya_output
# Pred tile: kenol1_1595 is written to kenya_output
# Pred tile: kenol1_1606 is written to kenya_output
# Pred tile: kenol1_1614 is written to kenya_output
# Pred tile: kenol1_1615 is written to kenya_output
# Pred tile: kenol1_1622 is written to kenya_output
# Pred tile: kenol1_1624 is written to kenya_output
# Pred tile: kenol1_1653 is written to kenya_output
# Pred tile: kenol1_1656 is written to kenya_output
# Pred tile: kenol1_1664 is written to kenya_output
# Pred tile: kenol1_1666 is written to kenya_output
# Pred tile: kenol1_1675 is written to kenya_output
# Pred tile: kenol1_1683 is written to kenya_output
# Pred tile: kenol1_1687 is written to kenya_output
# Pred tile: kenol1_1690 is written to kenya_output
# Pred tile: kenol1_1694 is written to kenya_output
# Pred tile: kenol1_1702 is written to kenya_output
# Pred tile: kenol1_1705 is written to kenya_output
# Pred tile: kenol1_1708 is written to kenya_output
# Pred tile: kenol1_1734 is written to kenya_output
# Pred tile: kenol1_1750 is written to kenya_output
# Pred tile: kenol1_1758 is written to kenya_output
# Pred tile: kenol1_1793 is written to kenya_output
# Pred tile: kenol1_1809 is written to kenya_output
# Pred tile: kenol1_1816 is written to kenya_output
# Pred tile: kenol1_1826 is written to kenya_output
# Pred tile: kenol1_1827 is written to kenya_output
# Pred tile: kenol1_1833 is written to kenya_output
# Pred tile: kenol1_1834 is written to kenya_output
# Pred tile: kenol1_1868 is written to kenya_output
# Pred tile: kenol1_1931 is written to kenya_output
# Pred tile: kenol1_1936 is written to kenya_output
# Pred tile: kenol1_1962 is written to kenya_output
# Pred tile: kenol1_1963 is written to kenya_output
# Pred tile: kenol1_1987 is written to kenya_output
# Pred tile: kenol1_1998 is written to kenya_output
# Pred tile: kenol1_2008 is written to kenya_output
# Pred tile: kenol1_2012 is written to kenya_output
# Pred tile: kenol1_2014 is written to kenya_output
# Pred tile: kenol1_2031 is written to kenya_output
# Pred tile: kenol1_2039 is written to kenya_output
# Pred tile: kenol1_2070 is written to kenya_output
# Pred tile: kenol1_2073 is written to kenya_output
# Pred tile: kenol1_2093 is written to kenya_output
# Pred tile: kenol1_2099 is written to kenya_output
# Pred tile: kenol1_2114 is written to kenya_output
# Pred tile: kenol1_2119 is written to kenya_output
# Pred tile: kenol1_2125 is written to kenya_output
# Pred tile: kenol1_2153 is written to kenya_output
# Pred tile: kenol1_2166 is written to kenya_output
# Pred tile: kenol1_2171 is written to kenya_output
# Pred tile: kenol1_2172 is written to kenya_output
# Pred tile: kenol1_2174 is written to kenya_output
# Pred tile: kenol1_2210 is written to kenya_output
# Pred tile: kenol1_2215 is written to kenya_output
# Pred tile: kenol1_2219 is written to kenya_output
# Pred tile: kenol1_2223 is written to kenya_output
# Pred tile: kenol1_2241 is written to kenya_output
# Pred tile: kenol1_2251 is written to kenya_output
# Pred tile: kenol1_2252 is written to kenya_output
# Pred tile: kenol1_2271 is written to kenya_output
# Pred tile: kenol1_236 is written to kenya_output
# Pred tile: kenol1_320 is written to kenya_output
# Pred tile: kenol1_324 is written to kenya_output
# Pred tile: kenol1_405 is written to kenya_output
# Pred tile: kenol1_414 is written to kenya_output
# Pred tile: kenol1_578 is written to kenya_output
# Pred tile: kenol1_583 is written to kenya_output
# Pred tile: kenol1_664 is written to kenya_output
# Pred tile: kenol1_741 is written to kenya_output
# Pred tile: kenol1_749 is written to kenya_output
# Pred tile: kenol1_751 is written to kenya_output
# Pred tile: kenol1_752 is written to kenya_output
# Pred tile: kenol1_753 is written to kenya_output
# Pred tile: kenol1_826 is written to kenya_output
# Pred tile: kenol1_827 is written to kenya_output
# Pred tile: kenol1_837 is written to kenya_output
# Pred tile: kenol2_1017 is written to kenya_output
# Pred tile: kenol2_1027 is written to kenya_output
# Pred tile: kenol2_1032 is written to kenya_output
# Pred tile: kenol2_1034 is written to kenya_output
# Pred tile: kenol2_1046 is written to kenya_output
# Pred tile: kenol2_1047 is written to kenya_output
# Pred tile: kenol2_1069 is written to kenya_output
# Pred tile: kenol2_1089 is written to kenya_output
# Pred tile: kenol2_1090 is written to kenya_output
# Pred tile: kenol2_1095 is written to kenya_output
# Pred tile: kenol2_1097 is written to kenya_output
# Pred tile: kenol2_1118 is written to kenya_output
# Pred tile: kenol2_1120 is written to kenya_output
# Pred tile: kenol2_1121 is written to kenya_output
# Pred tile: kenol2_1141 is written to kenya_output
# Pred tile: kenol2_1162 is written to kenya_output
# Pred tile: kenol2_1171 is written to kenya_output
# Pred tile: kenol2_1184 is written to kenya_output
# Pred tile: kenol2_1209 is written to kenya_output
# Pred tile: kenol2_1210 is written to kenya_output
# Pred tile: kenol2_1245 is written to kenya_output
# Pred tile: kenol2_1246 is written to kenya_output
# Pred tile: kenol2_1272 is written to kenya_output
# Pred tile: kenol2_1285 is written to kenya_output
# Pred tile: kenol2_1287 is written to kenya_output
# Pred tile: kenol2_1299 is written to kenya_output
# Pred tile: kenol2_1303 is written to kenya_output
# Pred tile: kenol2_1321 is written to kenya_output
# Pred tile: kenol2_1326 is written to kenya_output
# Pred tile: kenol2_1330 is written to kenya_output
# Pred tile: kenol2_1331 is written to kenya_output
# Pred tile: kenol2_1343 is written to kenya_output
# Pred tile: kenol2_1372 is written to kenya_output
# Pred tile: kenol2_1418 is written to kenya_output
# Pred tile: kenol2_1433 is written to kenya_output
# Pred tile: kenol2_1444 is written to kenya_output
# Pred tile: kenol2_1460 is written to kenya_output
# Pred tile: kenol2_1466 is written to kenya_output
# Pred tile: kenol2_1494 is written to kenya_output
# Pred tile: kenol2_1505 is written to kenya_output
# Pred tile: kenol2_1522 is written to kenya_output
# Pred tile: kenol2_1527 is written to kenya_output
# Pred tile: kenol2_1545 is written to kenya_output
# Pred tile: kenol2_1551 is written to kenya_output
# Pred tile: kenol2_1555 is written to kenya_output
# Pred tile: kenol2_1556 is written to kenya_output
# Pred tile: kenol2_1557 is written to kenya_output
# Pred tile: kenol2_1558 is written to kenya_output
# Pred tile: kenol2_1561 is written to kenya_output
# Pred tile: kenol2_1572 is written to kenya_output
# Pred tile: kenol2_1633 is written to kenya_output
# Pred tile: kenol2_1644 is written to kenya_output
# Pred tile: kenol2_1645 is written to kenya_output
# Pred tile: kenol2_1672 is written to kenya_output
# Pred tile: kenol2_1685 is written to kenya_output
# Pred tile: kenol2_1688 is written to kenya_output
# Pred tile: kenol2_1701 is written to kenya_output
# Pred tile: kenol2_1705 is written to kenya_output
# Pred tile: kenol2_361 is written to kenya_output
# Pred tile: kenol2_368 is written to kenya_output
# Pred tile: kenol2_373 is written to kenya_output
# Pred tile: kenol2_374 is written to kenya_output
# Pred tile: kenol2_435 is written to kenya_output
# Pred tile: kenol2_441 is written to kenya_output
# Pred tile: kenol2_451 is written to kenya_output
# Pred tile: kenol2_524 is written to kenya_output
# Pred tile: kenol2_579 is written to kenya_output
# Pred tile: kenol2_591 is written to kenya_output
# Pred tile: kenol2_593 is written to kenya_output
# Pred tile: kenol2_596 is written to kenya_output
# Pred tile: kenol2_598 is written to kenya_output
# Pred tile: kenol2_599 is written to kenya_output
# Pred tile: kenol2_652 is written to kenya_output
# Pred tile: kenol2_657 is written to kenya_output
# Pred tile: kenol2_668 is written to kenya_output
# Pred tile: kenol2_673 is written to kenya_output
# Pred tile: kenol2_680 is written to kenya_output
# Pred tile: kenol2_727 is written to kenya_output
# Pred tile: kenol2_744 is written to kenya_output
# Pred tile: kenol2_795 is written to kenya_output
# Pred tile: kenol2_798 is written to kenya_output
# Pred tile: kenol2_806 is written to kenya_output
# Pred tile: kenol2_824 is written to kenya_output
# Pred tile: kenol2_873 is written to kenya_output
# Pred tile: kenol2_904 is written to kenya_output
# Pred tile: kenol2_907 is written to kenya_output
# Pred tile: kenol2_946 is written to kenya_output
# Pred tile: kenol2_973 is written to kenya_output
# Pred tile: kenol2_975 is written to kenya_output
# ---------------- Prediction finished in 14s ----------------
